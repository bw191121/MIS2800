# %% [markdown]
# <a href="https://colab.research.google.com/github/bw191121/MIS2800/blob/main/ic3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install --upgrade pandas ipython-sql prettytable==3.10.1
# lines of code will run below for the installation
# an error will show at the end - that's expected and okay. You can ignore it.
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 kB 6.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.9/10.9 MB 96.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 59.9 MB/s eta 0:00:00
# ...
#   Attempting uninstall: prettytable
#     Found existing installation: prettytable 3.17.0
#     Uninstalling prettytable-3.17.0:
#       Successfully uninstalled prettytable-3.17.0
#   Attempting uninstall: pandas
#     Found existing installation: pandas 2.2.2
#     Uninstalling pandas-2.2.2:
#       Successfully uninstalled pandas-2.2.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires pandas==2.2.2, but you have pandas 3.0.0 which is incompatible.
# gradio 5.50.0 requires pandas<3.0,>=1.0, but you have pandas 3.0.0 which is incompatible.
# ...

# %%
# Install the SQL extension (not in sources, but required for magics)
# !pip install ipython-sql
print("ipython sql installed")
# lines of code will run below for the installation
# Out:
# ...
# ipython sql installed

# %%
# Load the SQL magic extension
# %load_ext sql

# %%
import sqlite3
print("sqlite3 imported")
# Out:
# sqlite3 imported

# %%
# This creates a brand-new, empty database file named 'SuperBowlMarketing2026.db'
conn = sqlite3.connect('SuperBowlMarketing2026.db')
print("database created")
# Out:
# database created

# %%
# %sql sqlite:///SuperBowlMarketing2026.db

# %%
# create a table called Marketing_Brands
# %%sql
CREATE TABLE Marketing_Brands (
  brand_id INTEGER PRIMARY KEY,
  brand_name TEXT,
  brand_type TEXT,
  brand_budget INTEGER
) STRICT;
# Out:
#  * sqlite:///SuperBowlMarketing2026.db
# Done.
# []

# %%
# create a table called Marketing_Brands
# %%sql
INSERT INTO Marketing_Brands (brand_id, brand_name, brand_type, brand_budget)
VALUES
  (1, 'Doritos', 'Snacks', 7000000),
  (2, 'AWS', 'Technology', 15000000),
  (3, 'Pepsi', 'Beverages', 2000000),
  (4, 'He_Gets_Us', 'Religious', 1000000),
  (5, 'Dr_Pepper', 'Beverages', 5000000),
  (6, 'IBM', 'Technology', 100000),
  (7, 'Google', 'Technology', 8000000);
# Out:
#  * sqlite:///SuperBowlMarketing2026.db
# 7 rows affected.
# []

# %%
# %%sql
# -- comments can be added by using the -- before the comment. notice that This is after the %%sql Magic
# SELECT * FROM Marketing_Brands;
# Out:
#  * sqlite:///SuperBowlMarketing2026.db
# Done.
# [(1, 'Doritos', 'Snacks', 7000000),
#  (2, 'AWS', 'Technology', 15000000),
#  (3, 'Pepsi', 'Beverages', 2000000),
#  (4, 'He_Gets_Us', 'Religious', 1000000),
#  (5, 'Dr_Pepper', 'Beverages', 5000000),
#  (6, 'IBM', 'Technology', 100000),
#  (7, 'Google', 'Technology', 8000000)]

# %%
# %%sql
# SELECT brand_name, brand_budget
# FROM Marketing_Brands
# WHERE brand_budget > 700000;
# Out:
#  * sqlite:///SuperBowlMarketing2026.db
# Done.
# [('Doritos', 7000000),
#  ('AWS', 15000000),
#  ('Pepsi', 2000000),
#  ('He_Gets_Us', 1000000),
#  ('Dr_Pepper', 5000000),
#  ('Google', 8000000)]

# %%
# %%sql
# SELECT brand_name, brand_type, brand_budget
# FROM Marketing_Brands
# WHERE brand_type = 'Technology' AND brand_budget < 1000000;
# Out:
#  * sqlite:///SuperBowlMarketing2026.db
# Done.
# [('IBM', 'Technology', 100000)]

# %%
# %%sql
# SELECT brand_name, brand_type, brand_budget
# FROM Marketing_Brands
# WHERE (brand_type = 'Snacks' OR brand_type = 'Beverages') AND brand_budget > 5000000;
# Out:
#  * sqlite:///SuperBowlMarketing2026.db
# Done.
# [('Doritos', 'Snacks', 7000000)]

# %%
# %%sql
# SELECT brand_name, brand_budget
# FROM Marketing_Brands
# WHERE brand_budget >= 7000000;
# Out:
#  * sqlite:///SuperBowlMarketing2026.db
# Done.
# [('Doritos', 7000000), ('AWS', 15000000), ('Google', 8000000)]

# %%
# %%sql
# SELECT brand_name, brand_type, brand_budget
# FROM Marketing_Brands
# WHERE brand_type = 'Beverages';
# Out:
#  * sqlite:///SuperBowlMarketing2026.db
# Done.
# [('Pepsi', 'Beverages', 2000000), ('Dr_Pepper', 'Beverages', 5000000)]

# %%
# %%sql
# SELECT brand_name, brand_type, brand_budget
# FROM Marketing_Brands
# ORDER BY brand_budget DESC;
# Out:
#  * sqlite:///SuperBowlMarketing2026.db
# Done.
# [('AWS', 'Technology', 15000000),
#  ('Google', 'Technology', 8000000),
#  ('Doritos', 'Snacks', 7000000),
#  ('Dr_Pepper', 'Beverages', 5000000),
#  ('Pepsi', 'Beverages', 2000000),
#  ('He_Gets_Us', 'Religious', 1000000),
#  ('IBM', 'Technology', 100000)]

# %%
# %%sql
# SELECT brand_name, brand_type, brand_budget
# FROM Marketing_Brands
# ORDER BY brand_name ASC;
# Out:
#  * sqlite:///SuperBowlMarketing2026.db
# Done.
# [('AWS', 'Technology', 15000000),
#  ('Doritos', 'Snacks', 7000000),
#  ('Dr_Pepper', 'Beverages', 5000000),
#  ('Google', 'Technology', 8000000),
#  ('He_Gets_Us', 'Religious', 1000000),
#  ('IBM', 'Technology', 100000),
#  ('Pepsi', 'Beverages', 2000000)]
